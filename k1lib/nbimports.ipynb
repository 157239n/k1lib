# %%
#export
"""These are pretty standard imports that I always
do. I put it here so that I can do::

    from k1lib.nbimports import *

and everything will be in place

This is slightly different than k1lib.imports, and optimizes a little
bit for the autocomplete of jupyter notebooks"""
from k1lib.imports import *
# Out:
# <style>
#     div.jp-OutputArea-output pre {white-space: pre;}
#     div.output_area pre {white-space: pre;}
#     div.CodeMirror > div.highlight {overflow-y: auto;}
# </style>

# %%
#export
fmt      = wrapMod(fmt)
knn      = wrapMod(knn)
selector = wrapMod(selector)
schedule = wrapMod(schedule)
viz      = wrapMod(viz)
k1ui     = wrapMod(k1ui)
p5       = wrapMod(p5)
kast     = wrapMod(kast)
serpent  = wrapMod(serpent)
kcom     = wrapMod(kcom)
kop      = wrapMod(kop)
kph      = wrapMod(kph)
kstr     = wrapMod(kstr)
kgis     = wrapMod(kgis)
assets   = wrapMod(assets)
web      = wrapMod(web)
eqn      = wrapMod(eqn)
zircon   = wrapMod(zircon)

# %%
# !../export.py nbimports --upload=True
# Out:
# ./export started up - /home/kelvin/envs/torch/bin/python
# ----- exportAll
# 17857   0   59%
# 12386   1   41%
# installing...
# Using Python 3.12.3 environment at: /home/kelvin/envs/torch
# Uninstalled 1 package in 2ms
#  - k1lib==1.8.2 (from file:///mnt/4-1/repos/labs/k1lib)
# Using Python 3.12.3 environment at: /home/kelvin/envs/torch
# Resolved 16 packages in 243ms
# Prepared 1 package in 177ms
# Installed 1 package in 1msfile:///mnt/4-1/repos/labs/k1lib)
#  + k1lib==1.8.2 (from file:///mnt/4-1/repos/labs/k1lib)
# installed
# uploading...
#
# Error encountered:
#
# * Creating isolated environment: venv+pip...
# * Installing packages in isolated environment:
#   - setuptools >= 40.8.0
# * Getting build dependencies for sdist...
# * Building sdist...
# * Building wheel from sdist
# * Creating isolated environment: venv+pip...
# * Installing packages in isolated environment:
#   - setuptools >= 40.8.0
# * Getting build dependencies for wheel...
# * Building wheel...
# uploaded

# %%
# !../export.py nbimports --bootstrap=True
# Out:
# Traceback (most recent call last):
#   File "/mnt/4-1/repos/labs/k1lib/k1lib/../export.py", line 16, in <module>
#     try: from k1lib.imports import *; hasK1 = True
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/4-1/repos/labs/k1lib/k1lib/__init__.py", line 19, in <module>
#     from . import zircon
#   File "/mnt/4-1/repos/labs/k1lib/k1lib/zircon.py", line 20, in <module>
#     from collections import defaultdict, deque; import k1lib.cli as cli; import k1lib.kws as kws
#                                                                          ^^^^^^^^^^^^^^^^^^^^^^^
# ModuleNotFoundError: No module named 'k1lib.kws'
# ./export started up - /home/kelvin/envs/torch/bin/python
# ----- bootstrapping
# Current dir: /mnt/4-1/repos/labs/k1lib, /mnt/4-1/repos/labs/k1lib/k1lib/../export.py
# installing...
# Using Python 3.14.3 environment at: /home/kelvin/envs/torch
# Uninstalled 1 package in 2ms
#  - k1lib==1.8.2 (from file:///mnt/4-1/repos/labs/k1lib)
# ...
