# %%
#export
"""
This is for functions that cuts out specific parts of the table
"""
from typing import Callable, Union, List, overload, Iterator, Any, Set, Tuple
from k1lib.bioinfo.cli.init import BaseCli, settings, Table, T
import k1lib.bioinfo.cli as cli
import k1lib, os
from collections import deque
# Out:
# <style>div.jp-OutputArea-output pre {white-space: pre;}</style>
# <style>div.output_area pre {white-space: pre;}</style>

# %%
#export
__all__ = ["filt", "isValue", "isFile", "inSet", "contains", "empty",
           "startswith", "endswith",
           "isNumeric", "instanceOf", "inRange",
           "head", "columns", "cut", "rows",
           "intersection", "union", "notIn", "unique", "breakIf"]

# %%
#export
class filt(BaseCli):
    def __init__(self, predicate:Callable[[T], bool], column:int=None):
        """Filters out lines.
Examples::

    # returns [2, 6]
    [2, 3, 5, 6] | filt(lambda x: x%2 == 0) | deref()
    # returns [3, 5]
    [2, 3, 5, 6] | ~filt(lambda x: x%2 == 0) | deref()
    # returns [[2, 'a'], [6, 'c']]
    [[2, "a"], [3, "b"], [5, "a"], [6, "c"]] | filt(lambda x: x%2 == 0, 0) | deref()

:param column:
    - if integer, then predicate(row[column])
    - if None, then predicate(row)"""
        super().__init__()
        self.predicate = predicate; self.column = column
    def __ror__(self, it:Iterator[T]) -> Iterator[T]:
        super().__ror__(it)
        p = self.predicate; c = self.column
        if c is None: yield from (l for l in it if p(l))
        else:
            for es in it:
                es = list(es)
                if c < len(es) and p(es[c]): yield es
    def __invert__(self):
        """Negate the condition"""
        return filt(lambda s: not self.predicate(s), self.column)

# %%
assert [2, 3, 5, 6] | filt(lambda x: x%2 == 0) | cli.deref() == [2, 6]
assert [2, 3, 5, 6] | ~filt(lambda x: x%2 == 0) | cli.deref() == [3, 5]
assert [[2, "a"], [3, "b"], [5, "a"], [6, "c"]] | filt(lambda x: x%2 == 0, 0) | cli.deref() == [[2, 'a'], [6, 'c']]

# %%
#export
def isValue(value, column:int=None) -> filt:
    """Filters out lines that is different from the given value.
Example::

    # returns [2, 2]
    [1, 2, 3, 2, 1] | isValue(2) | deref()
    # returns [1, 3, 1]
    [1, 2, 3, 2, 1] | ~isValue(2) | deref()
    # returns [[1, 2]]
    [[1, 2], [2, 1], [3, 4]] | isValue(2, 1) | deref()"""
    return filt(lambda l: l == value, column)

# %%
assert [1, 2, 3, 2, 1] | isValue(2) | cli.deref() == [2, 2]
assert [1, 2, 3, 2, 1] | ~isValue(2) | cli.deref() == [1, 3, 1]
assert [[1, 2], [2, 1], [3, 4]] | isValue(2, 1) | cli.deref() == [[1, 2]]

# %%
#export
def isFile() -> filt:
    """Filters out non-files.
Example::

    # returns ["a.py", "b.py"], if those files really do exist
    ["a.py", "hg/", "b.py"] | isFile()"""
    return filt(lambda l: os.path.isfile(l))

# %%
assert len(cli.ls("/home/kelvin") | ~isFile() | cli.deref()) > 0

# %%
#export
def inSet(values:Set[Any], column:int=None) -> filt:
    """Filters out lines that is not in the specified set.
Example::

    # returns [2, 3]
    range(5) | inSet([2, 8, 3]) | deref()
    # returns [0, 1, 4]
    range(5) | ~inSet([2, 8, 3]) | deref()"""
    values = set(values)
    return filt(lambda l: l in values, column)

# %%
assert range(5) | inSet([2, 8, 3]) | cli.deref() == [2, 3]
assert range(5) | ~inSet([2, 8, 3]) | cli.deref() == [0, 1, 4]

# %%
#export
def contains(s:str, column:int=None) -> filt:
    """Filters out lines that don't contain the specified substring. Sort of similar
to :class:`~k1lib.bioinfo.cli.grep.grep`, but this is simpler, and can be inverted.
Example::

    # returns ['abcd', '2bcr']
    ["abcd", "0123", "2bcr"] | contains("bc") | deref()"""
    return filt(lambda e: s in e, column)

# %%
assert ["abcd", "0123", "2bcr"] | contains("bc") | cli.deref() == ['abcd', '2bcr']

# %%
#export
class empty(BaseCli):
    def __init__(self, reverse=False):
        """Filters out streams that is not empty. Almost always used inverted,
but "empty" is a short, sweet name easy to remember. Example::

    # returns [[1, 2], ['a']]
    [[], [1, 2], [], ["a"]] | ~empty() | deref()

:param reverse: not intended to be used by the end user. Do ``~empty()`` instead."""
        super().__init__(); self.reverse = reverse
    def __ror__(self, streams:Iterator[Iterator[T]]) -> Iterator[Iterator[T]]:
        super().__ror__(streams); r = self.reverse
        for stream in streams:
            try:
                item, it = stream | cli.peek()
                if not r:
                    if it == []: yield it
                else:
                    if it != []: yield it
            except StopIteration: pass
    def __invert__(self):
        return empty(not self.reverse)

# %%
assert [[], [1, 2], [], ["a"]] | ~empty() | cli.deref() == [[1, 2], ['a']]

# %%
#export
def startswith(s:str, column:int=None) -> filt:
    """Filters out lines that don't start with `s`.
Example::

    # returns ['ab', 'ac']
    ["ab", "cd", "ac"] | startswith("a") | deref()
    # returns ['cd']
    ["ab", "cd", "ac"] | ~startswith("a") | deref()"""
    return filt(lambda l: l.startswith(s), column)
def endswith(s:str, column:int=None) -> filt:
    """Filters out lines that don't end with `s`. See also: :meth:`startswith`"""
    return filt(lambda l: l.endswith(s), column)

# %%
assert ["ab", "cd", "ac"] | startswith("a") | cli.deref() == ['ab', 'ac']
assert ["ab", "cd", "ac"] | ~startswith("a") | cli.deref() == ['cd']

# %%
#export
def isNumeric(column:int=None) -> filt:
    """Filters out a line if that column is not a number.
Example:

    # returns [0, 2, '3']
    [0, 2, "3", "a"] | isNumeric() | deref()"""
    def f(v):
        try: float(v); return True
        except ValueError: return False
    return filt(f, column)

# %%
assert [0, 2, "3", "a"] | isNumeric() | cli.deref() == [0, 2, '3']

# %%
#export
def instanceOf(cls:Union[type, Tuple[type]], column:int=None) -> filt:
    """Filters out lines that is not an instance of the given type.
Example::

    # returns [2]
    [2, 2.3, "a"] | instanceOf(int) | deref()
    # returns [2, 2.3]
    [2, 2.3, "a"] | instanceOf((int, float)) | deref()"""
    if isinstance(cls, list): cls = tuple(cls)
    return filt(lambda e: isinstance(e, cls), column)

# %%
assert [2, 2.3, "a"] | instanceOf(int) | cli.deref() == [2]
assert [2, 2.3, "a"] | instanceOf((int, float)) | cli.deref() == [2, 2.3]

# %%
#export
def inRange(min:float=float("-inf"), max:float=float("inf"), column:int=None) -> filt:
    """Checks whether a column is in range or not.
Example::

    # returns [-2, 3, 6]
    [-2, -8, 3, 6] | inRange(min=-3) | deref()
    # returns [-8]
    [-2, -8, 3, 6] | ~inRange(min=-3) | deref()"""
    return filt(lambda e: e >= min and e < max, column)

# %%
assert [-2, -8, 3, 6] | inRange(min=-3) | cli.deref() == [-2, 3, 6]
assert [-2, -8, 3, 6] | ~inRange(min=-3) | cli.deref() == [-8]

# %%
#export
class head(BaseCli):
    def __init__(self, n:int=10):
        """Only outputs first ``n`` lines. You can also negate it (like
``~head(5)``), which then only outputs after first ``n`` lines. Examples::

    "abcde" | head(2) | deref() # returns ["a", "b"]
    "abcde" | ~head(2) | deref() # returns ["c", "d", "e"]
    "0123456" | head(-3) | deref() # returns ['0', '1', '2', '3']
    "0123456" | ~head(-3) | deref() # returns ['4', '5', '6']"""
        super().__init__(); self.n = n; self.inverted = False
    def __ror__(self, it:Iterator[T]) -> Iterator[T]:
        super().__ror__(it); n = self.n
        if n >= 0:
            if not self.inverted:
                for i, line in enumerate(it):
                    if i >= n: return
                    yield line
            else:
                for i, line in enumerate(it):
                    if i < n: continue
                    yield line
        else:
            n = abs(n); queue = deque()
            if not self.inverted: # head to -3
                for line in it:
                    queue.append(line)
                    if len(queue) > n: yield queue.popleft()
            else: # -3 to end
                for line in it:
                    queue.append(line)
                    if len(queue) > n: queue.popleft()
                yield from queue
    def __invert__(self): self.inverted = not self.inverted; return self

# %%
assert "abcde" | head(2) | cli.deref() == ["a", "b"]
assert "abcde" | ~head(2) | cli.deref() == ["c", "d", "e"]
assert "0123456" | head(-3) | cli.deref() == ['0', '1', '2', '3']
assert "0123456" | ~head(-3) | cli.deref() == ['4', '5', '6']

# %%
#export
class rowsList(BaseCli):
    """Space-expensive implementation for :class:`rows`, without a lot of
flexibility. Just used for slices with negative start/stop really. Don't use
this directly, use :class:`rows` instead"""
    def __init__(self, _slice):
        super().__init__(); self._slice = _slice; self.inverted = False
    def __ror__(self, it:Iterator[str]):
        super().__ror__(it)
        it = list(it); full = range(len(it))
        rows = full[self._slice]
        if self.inverted: rows = [e for e in full if e not in rows]
        for row in rows: yield it[row]
    def __invert__(self): self.inverted = True; return self

# %%
#export
class rows(BaseCli):
    def __init__(self, *rows:List[int]):
        """Cuts out specific rows. Space complexity O(1) as a list is not
constructed (unless you're using some really weird slices).

:param rows: ints for the row indices

Example::

    "0123456789" | rows(2) | deref() # returns ["2"]
    "0123456789" | rows(5, 8) | deref() # returns ["5", "8"]
    "0123456789" | rows()[2:5] | deref() # returns ["2", "3", "4"]
    "0123456789" | ~rows()[2:5] | deref() # returns ["0", "1", "5", "6", "7", "8", "9"]
    "0123456789" | ~rows()[:7:2] | deref() # returns ['1', '3', '5', '7', '8', '9']
    "0123456789" | rows()[:-4] | deref() # returns ['0', '1', '2', '3', '4', '5']
    "0123456789" | ~rows()[:-4] | deref() # returns ['6', '7', '8', '9']"""
        super().__init__()
        if len(rows) == 1 and isinstance(rows[0], slice):
            s = rows[0]
            start = s.start if s.start is not None else float("-inf")
            stop = s.stop if s.stop is not None else float("inf")
            self.domain = k1lib.Domain([start, stop])
            self.every = s.step or 1 # only used for slices really
        else:
            self.domain = k1lib.Domain.fromInts(*rows)
            self.every = 1
        self.inverted = False
    def _every(self, every): self.every = every; return self
    def __getitem__(self, _slice):
        s1, s2 = _slice.start, _slice.stop
        a = (_slice.start or 0) < 0; b = (_slice.stop or 0) < 0
        c = (_slice.step or 1)
        if a or b: # at least 1 is negative
            if c == 1:
                if b:
                    if s1 is None: return head(s2) # [None, -3]
                    else: return ~head(s1) | head(s2) # [5, -3]
                if a and s2 is None: return ~head(s1) # [-3, None]
                # else case is [-10, 6], which is weird, so just stick to the long one
            return rowsList(_slice) # worst case scenario
        answer = rows(_slice); answer.inverted = self.inverted; return answer
    def __invert__(self): self.inverted = not self.inverted; return self
    def __ror__(self, it:Iterator[str]):
        super().__ror__(it)
        true, false = (False, True) if self.inverted else (True, False)
        def gates():
            gate = self.domain.intIter(self.every); x = 0
            for i in gate:
                while x < i: yield false; x += 1
                yield true; x += 1
            while True: yield false
        return (row for gate, row in zip(gates(), it) if gate)

# %%
assert "0123456789" | rows(5, 8) | cli.deref() == ['5', '8']
assert "0123456789" | rows(2) | cli.deref() == ['2']
assert "0123456789" | rows()[2:5] | cli.deref() == ["2", "3", "4"]
assert "0123456789" | ~rows()[2:5] | cli.deref() == ["0", "1", "5", "6", "7", "8", "9"]
assert "0123456789" | rows()[:7:2] | cli.deref() == ["0", "2", "4", "6"]
assert "0123456789" | ~rows()[:7:2] | cli.deref() == ['1', '3', '5', '7', '8', '9']
assert "0123456789" | rows()[:-4] | cli.deref() == ['0', '1', '2', '3', '4', '5']
assert "0123456789" | ~rows()[:-4] | cli.deref() == ['6', '7', '8', '9']

# %%
#export
class columns(BaseCli):
    def __init__(self, *columns:List[int]):
        """Cuts out specific columns, sliceable. Examples::

    ["0123456789"] | cut(5, 8) | deref() # returns [['5', '8']]
    ["0123456789"] | cut(2) | deref() # returns ['2']
    ["0123456789"] | cut(5, 8) | deref() # returns [['5', '8']]
    ["0123456789"] | ~cut()[:7:2] | deref() # returns [['1', '3', '5', '7', '8', '9']]

If you're selecting only 1 column, then Iterator[T] will be returned, not
Table[T]."""
        super().__init__()
        if len(columns) == 1 and isinstance(columns[0], slice): columns = columns[0]
        self.columns = columns; self.inverted = False
    def __ror__(self, it:Table[T]) -> Table[T]:
        super().__ror__(it)
        columns = self.columns; it = iter(it); row = None
        row, it = it | cli.peek()
        if row is None: return iter(range(0))
        row = list(row); rs = range(len(row))
        if isinstance(columns, slice): columns = set(rs[columns])
        if self.inverted: columns = set(e for e in rs if e not in columns)
        if len(columns) == 1: c = list(columns)[0]; return (row[c] for row in it)
        else: return ((e for i, e in enumerate(row) if i in columns) for row in it)
    def __getitem__(self, idx):
        answer = columns(idx); answer.inverted = self.inverted; return answer
    def __invert__(self): self.inverted = not self.inverted; return self
cut = columns

# %%
assert ["0123456789"] | cut(5, 8) | cli.deref() == [['5', '8']]
assert ["0123456789"] | cut(2) | cli.deref() == ['2']
assert ["0123456789"] | cut()[2:5] | cli.deref() == [["2", "3", "4"]]
assert ["0123456789"] | cut()[:7:2] | cli.deref() == [["0", "2", "4", "6"]]
assert ["0123456789"] | ~cut()[:7:2] | cli.deref() == [['1', '3', '5', '7', '8', '9']]
assert ["0123456789"] | ~cut()[2:5] | cli.deref() == [["0", "1", "5", "6", "7", "8", "9"]]

# %%
#export
class intersection(BaseCli):
    """Returns the intersection of multiple streams.
Example::

    # returns set([2, 4, 5])
    [[1, 2, 3, 4, 5], [7, 2, 4, 6, 5]] | intersection()"""
    def __ror__(self, its:Iterator[Iterator[Any]]) -> Set[Any]:
        answer = None
        for it in its:
            if answer is None: answer = set(it); continue
            answer = answer.intersection(it)
        return answer

# %%
assert [[1, 2, 3, 4, 5], [7, 2, 4, 6, 5]] | intersection() == set([2, 4, 5])

# %%
#export
class union(BaseCli):
    """Returns the union of multiple streams.
Example::

    # returns {0, 1, 2, 10, 11, 12, 13, 14}
    [range(3), range(10, 15)] | union()
"""
    def __ror__(self, its:Iterator[Iterator[Any]]) -> Set[Any]:
        answer = set()
        for it in its: answer = set.union(answer, set(it))
        return answer

# %%
assert [range(3), range(10, 15)] | union() == {0, 1, 2, 10, 11, 12, 13, 14}

# %%
#export
class notIn:
    def __init__(self, s:Iterator[T]):
        """Returns elements that are not in the specified list.
Example::

    # returns [-5, -4, -3, -2, -1, 10, 11]
    range(-5, 12) | notIn(range(10)) | deref()"""
        super().__init__(); self.s = set(s)
    def __ror__(self, it:Iterator[T]) -> Iterator[T]:
        s = self.s; return (r for r in it if r not in s)

# %%
assert range(-5, 12) | notIn(range(10)) | cli.deref() == [-5, -4, -3, -2, -1, 10, 11]

# %%
#export
class unique(BaseCli):
    def __init__(self, column:int):
        """Filters out non-unique row elements.
Example::

    # returns [[1, "a"], [2, "a"]]
    [[1, "a"], [2, "a"], [1, "b"]] | unique(0) | deref()

:param column: doesn't have the default case of None, because you can always use
    :class:`k1lib.bioinfo.cli.utils.toSet`"""
        super().__init__(); self.column = column
    def __ror__(self, it:Table[T]) -> Table[T]:
        self.__ror__(it); terms = set(); c = self.column
        for row in it:
            row = list(row); e = row[c]
            if e not in terms: yield row
            terms.add(e)

# %%
assert [[1, "a"], [2, "a"], [1, "b"]] | unique(0) | cli.deref() == [[1, 'a'], [2, 'a']]

# %%
#export
class breakIf(BaseCli):
    def __init__(self, f):
        """Breaks the input iterator if a condition is met.
Example::

    # returns [0, 1, 2, 3, 4, 5]
    [*range(10), 2, 3] | breakIf(lambda x: x > 5) | deref()"""
        super().__init__(); self.f = f
    def __ror__(self, it:Iterator[T]) -> Iterator[T]:
        super().__ror__(it); f = self.f
        for line in it:
            if f(line): break
            yield line

# %%
assert [*range(10), 2, 3] | breakIf(lambda x: x > 5) | cli.deref() == [0, 1, 2, 3, 4, 5]

# %%
# !../../../export.py bioinfo/cli/filt
# Out:
# Current dir: /home/kelvin/repos/labs/k1lib, ../../../export.py
# rm: cannot remove '__pycache__': No such file or directory
# Found existing installation: k1lib 0.2
# Uninstalling k1lib-0.2:
#   Successfully uninstalled k1lib-0.2
# running install
# running bdist_egg
# running egg_info
# creating k1lib.egg-info
# writing k1lib.egg-info/PKG-INFO
# writing dependency_links to k1lib.egg-info/dependency_links.txt
# writing requirements to k1lib.egg-info/requires.txt
# writing top-level names to k1lib.egg-info/top_level.txt
# writing manifest file 'k1lib.egg-info/SOURCES.txt'
# reading manifest file 'k1lib.egg-info/SOURCES.txt'
# writing manifest file 'k1lib.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/k1lib
# copying k1lib/_learner.py -> build/lib/k1lib
# copying k1lib/data.py -> build/lib/k1lib
# copying k1lib/selector.py -> build/lib/k1lib
# copying k1lib/imports.py -> build/lib/k1lib
# copying k1lib/_basics.py -> build/lib/k1lib
# copying k1lib/format.py -> build/lib/k1lib
# copying k1lib/nn.py -> build/lib/k1lib
# copying k1lib/viz.py -> build/lib/k1lib
# copying k1lib/__init__.py -> build/lib/k1lib
# copying k1lib/graphEqn.py -> build/lib/k1lib
# copying k1lib/schedule.py -> build/lib/k1lib
# copying k1lib/website.py -> build/lib/k1lib
# copying k1lib/eqn.py -> build/lib/k1lib
# creating build/lib/k1lib/_hidden
# copying k1lib/_hidden/hiddenFile.py -> build/lib/k1lib/_hidden
# copying k1lib/_hidden/__init__.py -> build/lib/k1lib/_hidden
# creating build/lib/k1lib/bioinfo
# copying k1lib/bioinfo/__init__.py -> build/lib/k1lib/bioinfo
# creating build/lib/k1lib/bioinfo/cli
# copying k1lib/bioinfo/cli/bio.py -> build/lib/k1lib/bioinfo/cli
# copying k1lib/bioinfo/cli/ctx.py -> build/lib/k1lib/bioinfo/cli
# copying k1lib/bioinfo/cli/structural.py -> build/lib/k1lib/bioinfo/cli
# copying k1lib/bioinfo/cli/modifier.py -> build/lib/k1lib/bioinfo/cli
# copying k1lib/bioinfo/cli/gb.py -> build/lib/k1lib/bioinfo/cli
# copying k1lib/bioinfo/cli/output.py -> build/lib/k1lib/bioinfo/cli
# copying k1lib/bioinfo/cli/kxml.py -> build/lib/k1lib/bioinfo/cli
# copying k1lib/bioinfo/cli/inp.py -> build/lib/k1lib/bioinfo/cli
# copying k1lib/bioinfo/cli/mgi.py -> build/lib/k1lib/bioinfo/cli
# copying k1lib/bioinfo/cli/grep.py -> build/lib/k1lib/bioinfo/cli
# copying k1lib/bioinfo/cli/sam.py -> build/lib/k1lib/bioinfo/cli
# copying k1lib/bioinfo/cli/entrez.py -> build/lib/k1lib/bioinfo/cli
# copying k1lib/bioinfo/cli/__init__.py -> build/lib/k1lib/bioinfo/cli
# copying k1lib/bioinfo/cli/filt.py -> build/lib/k1lib/bioinfo/cli
# copying k1lib/bioinfo/cli/utils.py -> build/lib/k1lib/bioinfo/cli
# copying k1lib/bioinfo/cli/init.py -> build/lib/k1lib/bioinfo/cli
# copying k1lib/bioinfo/cli/_ctx.py -> build/lib/k1lib/bioinfo/cli
# copying k1lib/bioinfo/cli/kcsv.py -> build/lib/k1lib/bioinfo/cli
# creating build/lib/k1lib/callbacks
# copying k1lib/callbacks/loss_accuracy.py -> build/lib/k1lib/callbacks
# copying k1lib/callbacks/progress.py -> build/lib/k1lib/callbacks
# copying k1lib/callbacks/limits.py -> build/lib/k1lib/callbacks
# copying k1lib/callbacks/hookParam.py -> build/lib/k1lib/callbacks
# copying k1lib/callbacks/profiler.py -> build/lib/k1lib/callbacks
# copying k1lib/callbacks/callbacks.py -> build/lib/k1lib/callbacks
# copying k1lib/callbacks/paramFinder.py -> build/lib/k1lib/callbacks
# copying k1lib/callbacks/core.py -> build/lib/k1lib/callbacks
# copying k1lib/callbacks/__init__.py -> build/lib/k1lib/callbacks
# copying k1lib/callbacks/landscape.py -> build/lib/k1lib/callbacks
# copying k1lib/callbacks/confusionMatrix.py -> build/lib/k1lib/callbacks
# copying k1lib/callbacks/frozen.py -> build/lib/k1lib/callbacks
# copying k1lib/callbacks/recorder.py -> build/lib/k1lib/callbacks
# copying k1lib/callbacks/shorts.py -> build/lib/k1lib/callbacks
# copying k1lib/callbacks/hookModule.py -> build/lib/k1lib/callbacks
# creating build/lib/k1lib/callbacks/profilers
# copying k1lib/callbacks/profilers/time.py -> build/lib/k1lib/callbacks/profilers
# copying k1lib/callbacks/profilers/memory.py -> build/lib/k1lib/callbacks/profilers
# copying k1lib/callbacks/profilers/__init__.py -> build/lib/k1lib/callbacks/profilers
# copying k1lib/callbacks/profilers/io.py -> build/lib/k1lib/callbacks/profilers
# copying k1lib/callbacks/profilers/computation.py -> build/lib/k1lib/callbacks/profilers
# creating build/lib/k1lib/callbacks/lossFunctions
# copying k1lib/callbacks/lossFunctions/__init__.py -> build/lib/k1lib/callbacks/lossFunctions
# copying k1lib/callbacks/lossFunctions/shorts.py -> build/lib/k1lib/callbacks/lossFunctions
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/k1lib
# copying build/lib/k1lib/_learner.py -> build/bdist.linux-x86_64/egg/k1lib
# copying build/lib/k1lib/data.py -> build/bdist.linux-x86_64/egg/k1lib
# copying build/lib/k1lib/selector.py -> build/bdist.linux-x86_64/egg/k1lib
# copying build/lib/k1lib/imports.py -> build/bdist.linux-x86_64/egg/k1lib
# copying build/lib/k1lib/_basics.py -> build/bdist.linux-x86_64/egg/k1lib
# copying build/lib/k1lib/format.py -> build/bdist.linux-x86_64/egg/k1lib
# copying build/lib/k1lib/nn.py -> build/bdist.linux-x86_64/egg/k1lib
# copying build/lib/k1lib/viz.py -> build/bdist.linux-x86_64/egg/k1lib
# copying build/lib/k1lib/__init__.py -> build/bdist.linux-x86_64/egg/k1lib
# copying build/lib/k1lib/graphEqn.py -> build/bdist.linux-x86_64/egg/k1lib
# copying build/lib/k1lib/schedule.py -> build/bdist.linux-x86_64/egg/k1lib
# copying build/lib/k1lib/website.py -> build/bdist.linux-x86_64/egg/k1lib
# creating build/bdist.linux-x86_64/egg/k1lib/callbacks
# copying build/lib/k1lib/callbacks/loss_accuracy.py -> build/bdist.linux-x86_64/egg/k1lib/callbacks
# copying build/lib/k1lib/callbacks/progress.py -> build/bdist.linux-x86_64/egg/k1lib/callbacks
# copying build/lib/k1lib/callbacks/limits.py -> build/bdist.linux-x86_64/egg/k1lib/callbacks
# copying build/lib/k1lib/callbacks/hookParam.py -> build/bdist.linux-x86_64/egg/k1lib/callbacks
# copying build/lib/k1lib/callbacks/profiler.py -> build/bdist.linux-x86_64/egg/k1lib/callbacks
# copying build/lib/k1lib/callbacks/callbacks.py -> build/bdist.linux-x86_64/egg/k1lib/callbacks
# copying build/lib/k1lib/callbacks/paramFinder.py -> build/bdist.linux-x86_64/egg/k1lib/callbacks
# copying build/lib/k1lib/callbacks/core.py -> build/bdist.linux-x86_64/egg/k1lib/callbacks
# creating build/bdist.linux-x86_64/egg/k1lib/callbacks/profilers
# copying build/lib/k1lib/callbacks/profilers/time.py -> build/bdist.linux-x86_64/egg/k1lib/callbacks/profilers
# copying build/lib/k1lib/callbacks/profilers/memory.py -> build/bdist.linux-x86_64/egg/k1lib/callbacks/profilers
# copying build/lib/k1lib/callbacks/profilers/__init__.py -> build/bdist.linux-x86_64/egg/k1lib/callbacks/profilers
# copying build/lib/k1lib/callbacks/profilers/io.py -> build/bdist.linux-x86_64/egg/k1lib/callbacks/profilers
# copying build/lib/k1lib/callbacks/profilers/computation.py -> build/bdist.linux-x86_64/egg/k1lib/callbacks/profilers
# copying build/lib/k1lib/callbacks/__init__.py -> build/bdist.linux-x86_64/egg/k1lib/callbacks
# copying build/lib/k1lib/callbacks/landscape.py -> build/bdist.linux-x86_64/egg/k1lib/callbacks
# copying build/lib/k1lib/callbacks/confusionMatrix.py -> build/bdist.linux-x86_64/egg/k1lib/callbacks
# copying build/lib/k1lib/callbacks/frozen.py -> build/bdist.linux-x86_64/egg/k1lib/callbacks
# copying build/lib/k1lib/callbacks/recorder.py -> build/bdist.linux-x86_64/egg/k1lib/callbacks
# copying build/lib/k1lib/callbacks/shorts.py -> build/bdist.linux-x86_64/egg/k1lib/callbacks
# copying build/lib/k1lib/callbacks/hookModule.py -> build/bdist.linux-x86_64/egg/k1lib/callbacks
# creating build/bdist.linux-x86_64/egg/k1lib/callbacks/lossFunctions
# copying build/lib/k1lib/callbacks/lossFunctions/__init__.py -> build/bdist.linux-x86_64/egg/k1lib/callbacks/lossFunctions
# copying build/lib/k1lib/callbacks/lossFunctions/shorts.py -> build/bdist.linux-x86_64/egg/k1lib/callbacks/lossFunctions
# creating build/bdist.linux-x86_64/egg/k1lib/_hidden
# copying build/lib/k1lib/_hidden/hiddenFile.py -> build/bdist.linux-x86_64/egg/k1lib/_hidden
# copying build/lib/k1lib/_hidden/__init__.py -> build/bdist.linux-x86_64/egg/k1lib/_hidden
# copying build/lib/k1lib/eqn.py -> build/bdist.linux-x86_64/egg/k1lib
# creating build/bdist.linux-x86_64/egg/k1lib/bioinfo
# creating build/bdist.linux-x86_64/egg/k1lib/bioinfo/cli
# copying build/lib/k1lib/bioinfo/cli/bio.py -> build/bdist.linux-x86_64/egg/k1lib/bioinfo/cli
# copying build/lib/k1lib/bioinfo/cli/ctx.py -> build/bdist.linux-x86_64/egg/k1lib/bioinfo/cli
# copying build/lib/k1lib/bioinfo/cli/structural.py -> build/bdist.linux-x86_64/egg/k1lib/bioinfo/cli
# copying build/lib/k1lib/bioinfo/cli/modifier.py -> build/bdist.linux-x86_64/egg/k1lib/bioinfo/cli
# copying build/lib/k1lib/bioinfo/cli/gb.py -> build/bdist.linux-x86_64/egg/k1lib/bioinfo/cli
# copying build/lib/k1lib/bioinfo/cli/output.py -> build/bdist.linux-x86_64/egg/k1lib/bioinfo/cli
# copying build/lib/k1lib/bioinfo/cli/kxml.py -> build/bdist.linux-x86_64/egg/k1lib/bioinfo/cli
# copying build/lib/k1lib/bioinfo/cli/inp.py -> build/bdist.linux-x86_64/egg/k1lib/bioinfo/cli
# copying build/lib/k1lib/bioinfo/cli/mgi.py -> build/bdist.linux-x86_64/egg/k1lib/bioinfo/cli
# copying build/lib/k1lib/bioinfo/cli/grep.py -> build/bdist.linux-x86_64/egg/k1lib/bioinfo/cli
# copying build/lib/k1lib/bioinfo/cli/sam.py -> build/bdist.linux-x86_64/egg/k1lib/bioinfo/cli
# copying build/lib/k1lib/bioinfo/cli/entrez.py -> build/bdist.linux-x86_64/egg/k1lib/bioinfo/cli
# copying build/lib/k1lib/bioinfo/cli/__init__.py -> build/bdist.linux-x86_64/egg/k1lib/bioinfo/cli
# copying build/lib/k1lib/bioinfo/cli/filt.py -> build/bdist.linux-x86_64/egg/k1lib/bioinfo/cli
# copying build/lib/k1lib/bioinfo/cli/utils.py -> build/bdist.linux-x86_64/egg/k1lib/bioinfo/cli
# copying build/lib/k1lib/bioinfo/cli/init.py -> build/bdist.linux-x86_64/egg/k1lib/bioinfo/cli
# copying build/lib/k1lib/bioinfo/cli/_ctx.py -> build/bdist.linux-x86_64/egg/k1lib/bioinfo/cli
# copying build/lib/k1lib/bioinfo/cli/kcsv.py -> build/bdist.linux-x86_64/egg/k1lib/bioinfo/cli
# copying build/lib/k1lib/bioinfo/__init__.py -> build/bdist.linux-x86_64/egg/k1lib/bioinfo
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/_learner.py to _learner.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/data.py to data.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/selector.py to selector.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/imports.py to imports.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/_basics.py to _basics.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/format.py to format.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/nn.py to nn.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/viz.py to viz.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/__init__.py to __init__.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/graphEqn.py to graphEqn.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/schedule.py to schedule.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/website.py to website.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/callbacks/loss_accuracy.py to loss_accuracy.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/callbacks/progress.py to progress.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/callbacks/limits.py to limits.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/callbacks/hookParam.py to hookParam.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/callbacks/profiler.py to profiler.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/callbacks/callbacks.py to callbacks.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/callbacks/paramFinder.py to paramFinder.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/callbacks/core.py to core.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/callbacks/profilers/time.py to time.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/callbacks/profilers/memory.py to memory.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/callbacks/profilers/__init__.py to __init__.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/callbacks/profilers/io.py to io.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/callbacks/profilers/computation.py to computation.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/callbacks/__init__.py to __init__.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/callbacks/landscape.py to landscape.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/callbacks/confusionMatrix.py to confusionMatrix.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/callbacks/frozen.py to frozen.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/callbacks/recorder.py to recorder.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/callbacks/shorts.py to shorts.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/callbacks/hookModule.py to hookModule.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/callbacks/lossFunctions/__init__.py to __init__.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/callbacks/lossFunctions/shorts.py to shorts.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/_hidden/hiddenFile.py to hiddenFile.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/_hidden/__init__.py to __init__.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/eqn.py to eqn.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/bioinfo/cli/bio.py to bio.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/bioinfo/cli/ctx.py to ctx.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/bioinfo/cli/structural.py to structural.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/bioinfo/cli/modifier.py to modifier.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/bioinfo/cli/gb.py to gb.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/bioinfo/cli/output.py to output.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/bioinfo/cli/kxml.py to kxml.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/bioinfo/cli/inp.py to inp.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/bioinfo/cli/mgi.py to mgi.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/bioinfo/cli/grep.py to grep.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/bioinfo/cli/sam.py to sam.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/bioinfo/cli/entrez.py to entrez.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/bioinfo/cli/__init__.py to __init__.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/bioinfo/cli/filt.py to filt.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/bioinfo/cli/utils.py to utils.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/bioinfo/cli/init.py to init.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/bioinfo/cli/_ctx.py to _ctx.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/bioinfo/cli/kcsv.py to kcsv.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/k1lib/bioinfo/__init__.py to __init__.cpython-38.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying k1lib.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying k1lib.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying k1lib.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying k1lib.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying k1lib.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# creating dist
# creating 'dist/k1lib-0.2-py3.8.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing k1lib-0.2-py3.8.egg
# Copying k1lib-0.2-py3.8.egg to /home/kelvin/anaconda3/envs/torch/lib/python3.8/site-packages
# Adding k1lib 0.2 to easy-install.pth file
#
# Installed /home/kelvin/anaconda3/envs/torch/lib/python3.8/site-packages/k1lib-0.2-py3.8.egg
# Processing dependencies for k1lib==0.2
# Searching for dill==0.3.4
# Best match: dill 0.3.4
# Adding dill 0.3.4 to easy-install.pth file
#
# Using /home/kelvin/anaconda3/envs/torch/lib/python3.8/site-packages
# Searching for matplotlib==3.3.2
# Best match: matplotlib 3.3.2
# Adding matplotlib 3.3.2 to easy-install.pth file
#
# Using /home/kelvin/anaconda3/envs/torch/lib/python3.8/site-packages
# Searching for numpy==1.19.2
# Best match: numpy 1.19.2
# Adding numpy 1.19.2 to easy-install.pth file
# Installing f2py script to /home/kelvin/anaconda3/envs/torch/bin
# Installing f2py3 script to /home/kelvin/anaconda3/envs/torch/bin
# Installing f2py3.8 script to /home/kelvin/anaconda3/envs/torch/bin
#
# Using /home/kelvin/anaconda3/envs/torch/lib/python3.8/site-packages
# Searching for torch==1.9.0
# Best match: torch 1.9.0
# Adding torch 1.9.0 to easy-install.pth file
# Installing convert-caffe2-to-onnx script to /home/kelvin/anaconda3/envs/torch/bin
# Installing convert-onnx-to-caffe2 script to /home/kelvin/anaconda3/envs/torch/bin
#
# Using /home/kelvin/anaconda3/envs/torch/lib/python3.8/site-packages
# Searching for certifi==2021.5.30
# Best match: certifi 2021.5.30
# Adding certifi 2021.5.30 to easy-install.pth file
#
# Using /home/kelvin/anaconda3/envs/torch/lib/python3.8/site-packages
# Searching for cycler==0.10.0
# Best match: cycler 0.10.0
# Adding cycler 0.10.0 to easy-install.pth file
#
# Using /home/kelvin/anaconda3/envs/torch/lib/python3.8/site-packages
# Searching for pyparsing==2.4.7
# Best match: pyparsing 2.4.7
# Adding pyparsing 2.4.7 to easy-install.pth file
#
# Using /home/kelvin/anaconda3/envs/torch/lib/python3.8/site-packages
# Searching for python-dateutil==2.8.1
# Best match: python-dateutil 2.8.1
# Adding python-dateutil 2.8.1 to easy-install.pth file
#
# Using /home/kelvin/anaconda3/envs/torch/lib/python3.8/site-packages
# Searching for kiwisolver==1.3.1
# Best match: kiwisolver 1.3.1
# Adding kiwisolver 1.3.1 to easy-install.pth file
#
# Using /home/kelvin/anaconda3/envs/torch/lib/python3.8/site-packages
# Searching for Pillow==7.2.0
# Best match: Pillow 7.2.0
# Adding Pillow 7.2.0 to easy-install.pth file
#
# Using /home/kelvin/anaconda3/envs/torch/lib/python3.8/site-packages
# Searching for typing-extensions==3.10.0.0
# Best match: typing-extensions 3.10.0.0
# Adding typing-extensions 3.10.0.0 to easy-install.pth file
#
# Using /home/kelvin/anaconda3/envs/torch/lib/python3.8/site-packages
# Searching for six==1.16.0
# Best match: six 1.16.0
# Adding six 1.16.0 to easy-install.pth file
#
# Using /home/kelvin/anaconda3/envs/torch/lib/python3.8/site-packages
# Finished processing dependencies for k1lib==0.2
